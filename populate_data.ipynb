# %%
# !pip install langchain-huggingface
# !pip install huggingface_hub
# !pip install langchain
# !pip install chromadb
# !pip install pypdf
# !pip install pytest
# Out:
# Requirement already satisfied: langchain-huggingface in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (0.0.3)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-huggingface) (0.23.4)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-huggingface) (0.2.22)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-huggingface) (3.0.1)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-huggingface) (0.19.1)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-huggingface) (4.42.3)
# Requirement already satisfied: filelock in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (6.0.1)
# Requirement already satisfied: requests in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub>=0.23.0->langchain-huggingface) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (0.1.82)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (2.7.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.3,>=0.1.52->langchain-huggingface) (8.4.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.3.1)
# Requirement already satisfied: numpy in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.5.1)
# Requirement already satisfied: scipy in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.14.0)
# Requirement already satisfied: Pillow in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (10.4.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (0.4.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.52->langchain-huggingface) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.1.52->langchain-huggingface) (3.10.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.52->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.3,>=0.1.52->langchain-huggingface) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface-hub>=0.23.0->langchain-huggingface) (2024.6.2)
# Requirement already satisfied: sympy in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.12.1)
# Requirement already satisfied: networkx in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.3)
# Requirement already satisfied: jinja2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.4)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.23.0->langchain-huggingface) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (3.5.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2021.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: huggingface_hub in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (0.23.4)
# Requirement already satisfied: filelock in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: colorama in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->huggingface_hub) (2024.6.2)
# Requirement already satisfied: langchain in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (0.2.10)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.22 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.2.22)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (0.1.82)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.7.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.3.0,>=0.2.22->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain-core<0.3.0,>=0.2.22->langchain) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.22->langchain) (3.0.0)
# Requirement already satisfied: chromadb in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (0.5.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (2.7.4)
# Requirement already satisfied: chroma-hnswlib==0.7.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.7.5)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.111.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.30.3)
# Requirement already satisfied: numpy<2.0.0,>=1.22.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.18.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.25.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (1.65.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (30.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (8.4.2)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (3.10.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: colorama in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.4)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Requirement already satisfied: python-multipart>=0.0.7 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from fastapi>=0.95.2->chromadb) (2.2.0)
# Requirement already satisfied: anyio in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (4.4.0)
# Requirement already satisfied: certifi in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.5)
# Requirement already satisfied: idna in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.2)
# Requirement already satisfied: coloredlogs in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.25.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.46b0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.46b0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: opentelemetry-util-http==0.46b0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.46b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (70.1.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=1.9->chromadb) (2.18.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.23.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.0)
# Requirement already satisfied: pypdf in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (4.3.0)
# Requirement already satisfied: pytest in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (8.2.2)
# Requirement already satisfied: iniconfig in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pytest) (2.0.0)
# Requirement already satisfied: packaging in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pytest) (24.1)
# Requirement already satisfied: pluggy<2.0,>=1.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pytest) (1.5.0)
# Requirement already satisfied: colorama in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pytest) (0.4.6)

# %%
# !pip install langchain_core
# Out:
# Requirement already satisfied: langchain_core in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (0.2.22)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain_core) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain_core) (0.1.82)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain_core) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain_core) (2.7.4)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langchain_core) (8.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain_core) (3.10.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain_core) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain_core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain_core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain_core) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\samarth gowda\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain_core) (2024.6.2)

# %%
#loading pdf data 
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
DATA_PATH = "Data"

def load_documents():
    document_loader= PyPDFDirectoryLoader(DATA_PATH)
    return document_loader.load()

# %%
documents=load_documents()
print(documents[0])
# Out:
# page_content='MONOPOLY
# Property Trading Game from Parker Brothers"
# AGES 8+
# 2 to 8 Players
# Contents: Gameboard, 3 dice, tokens, 32 houses, I2 hotels, Chance
# and Community Chest cards, Title Deed cards, play money and a Banker's tray.
# Now there's a faster way to play MONOPOLY. Choose to play by
# the classic rules for buying, renting and selling properties or use the
# Speed Die to get into the action faster. If you've never played the classic
# MONOPOLY game, refer to the Classic Rules beginning on the next page.
# If you already know how to play and want to use the Speed Die, just
# read the section below for the additional Speed Die rules.
# SPEED DIE RULES
# Learnins how to Play with the S~eed Die IS as
# /
# fast as playing with i't.
# 1. When starting the game, hand out an extra $1,000 to each player
# (two $5005 should work). The game moves fast and you'll need
# the extra cash to buy and build.
# 2. Do not use the Speed Die until you've landed on or passed over
# GO for the first time. Once you collect that first $200 salary, you'll
# use the Speed Die for the rest of the game. This means that some
# players will start using the die before others.
# 3. Once you start using the Speed Die, roll it along with the two
# white dice on your turn. Then do the following depending on
# what you rolled.
# 1, 2, or 3: Add this number to the roll of the two white
# dice. You'll zoom around the board. ' metadata={'source': 'Data\\monopoly.pdf', 'page': 0}

# %%
#Split the documents 
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema.document import Document

def split_documents(documents: list[Document]):
    
    text_splitter = RecursiveCharacterTextSplitter(
        # Set a really small chunk size, just to show.
        chunk_size=500,
        chunk_overlap=80,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_documents(documents)

# %%
chunks= split_documents(documents)
print(chunks[2])
# Out:
# page_content='1. When starting the game, hand out an extra $1,000 to each player
# (two $5005 should work). The game moves fast and you'll need
# the extra cash to buy and build.
# 2. Do not use the Speed Die until you've landed on or passed over
# GO for the first time. Once you collect that first $200 salary, you'll
# use the Speed Die for the rest of the game. This means that some
# players will start using the die before others.
# 3. Once you start using the Speed Die, roll it along with the two' metadata={'source': 'Data\\monopoly.pdf', 'page': 0}

# %%
from langchain_community.embeddings import HuggingFaceInferenceAPIEmbeddings
from secret_key import huggingface_key

def get_embedding_function():
    
    embeddings = HuggingFaceInferenceAPIEmbeddings(
        api_key=huggingface_key, model_name="sentence-transformers/all-MiniLM-l6-v2"
    )
    #print(huggingface_key)
    return embeddings

# %%
#setting chunk id

def calculate_chunk_ids(chunks):
    last_page_id= None
    current_chunk_index= 0 
    
    for chunk in chunks:
        source= chunk.metadata.get("source")
        page= chunk.metadata.get("page")
        current_page_id= f"{source}:{page}"
    
        #if the current and last page ID are the same increment the chunk index.
        if current_page_id == last_page_id:
            current_chunk_index +=1
        else:
            current_chunk_index = 0
    
        #calculate chunk index
        chunk_id = f"{current_page_id}:{current_chunk_index}"
        last_page_id = current_page_id
    
        #add it to the page metadata
        chunk.metadata["id"]=chunk_id
    
    return chunks

# %%
from get_embedding_function import get_embedding_function
from langchain.vectorstores.chroma import Chroma 
CHROMA_PATH= "chroma"
def add_to_chroma(chunks: list[Document]):
    db= Chroma(
        persist_directory=CHROMA_PATH, embedding_function=get_embedding_function()
    )

    #calculate chunk ids
    chunks_with_ids = calculate_chunk_ids(chunks)
    
    #add or update the documents.
    existing_items = db.get(include=[])
    existing_ids = set(existing_items["ids"])
    print(f"Number of existing documents in DB: {len(existing_ids)}")

    #only add new chunks to the db.
    new_chunks = []
    for chunk in chunks_with_ids:
        if chunk.metadata["id"] not in existing_ids:
            new_chunks.append(chunk)

    if len(new_chunks):
        print(f"👉Adding new documents: {len(new_chunks)}")
        new_chunk_ids = [chunk.metadata["id"] for chunk in new_chunks]
        db.add_documents(new_chunks, ids=new_chunk_ids)
        db.persist()
    else:
        print(f"✅no new documents to add")

# %%
add_to_chroma(chunks)
# Out:
# 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
# Number of existing documents in DB: 95
# ✅no new documents to add

# %%
import os 
from langchain import PromptTemplate, LLMChain
from langchain.prompts import ChatPromptTemplate
from langchain_huggingface import HuggingFaceEndpoint

CHROMA_PATH= "chroma"

PROMPT_TEMPLATE= """
Query:
{Question}

----

Answer based on the chunks that best match the query:
{Context}
"""
parser.arg

def rag_query(query_text: str):

    # Redefine the same embedding function that was used for the database. 
    embedding_function = get_embedding_function()
    db= Chroma(
        persist_directory=CHROMA_PATH, embedding_function=embedding_function
    )

    # Search query in the database to find k most similar chunks
    result= db.cosine_similarity(query_text, k=5)
    #db.similarity_search_with_score(query_text, k=5)

    # Create a final prompt with relevant context and query to pass to the LLM.
    context_text= "\n\n-------------\n\n".join([doc.page_content for doc, _score in result])
    prompt_template= ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
    prompt=prompt_template.format(Question= query_text, Context= context_text)


    repo_id="mistralai/Mistral-7B-Instruct-v0.3"
    token=huggingface_key


    llm=HuggingFaceEndpoint(
        repo_id=repo_id,
        max_length=128,
        temperature=0.6,
        token=token)

    response_text= llm.invoke(prompt)
    return(response_text)

# %%
print(huggingface_key)
# Out:
# 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
